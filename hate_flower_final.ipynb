# %% [markdown]
# # Federated Learning using Hugging Face and Flower
#
# This tutorial will show how to leverage Hugging Face to federate the training of language models over multiple clients using [Flower](https://flower.dev/). More specifically, we will fine-tune a pre-trained Transformer model (alBERT) for sequence classification over a dataset of IMDB ratings. The end goal is to detect if a movie rating is positive or negative.

# %% [markdown]
# ## Dependencies
#
# For this tutorial we will need `datasets`, `flwr['simulation']`(here we use the extra 'simulation' dependencies from Flower as we will simulated the federated setting inside Google Colab), `torch`, and `transformers`.

# %%
# !pip install datasets evaluate flwr["simulation"] torch transformers scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 11.4 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 4.8 MB/s eta 0:00:00
# Collecting flwr[simulation]
#   Downloading flwr-1.4.0-py3-none-any.whl (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.2/157.2 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 35.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 9.7 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 10.6 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 8.7 MB/s eta 0:00:00
# Collecting iterators<0.0.3,>=0.0.2
#   Downloading iterators-0.0.2-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: protobuf<4.0.0,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from flwr[simulation]) (3.20.3)
# Requirement already satisfied: grpcio!=1.52.0,<2.0.0,>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from flwr[simulation]) (1.54.0)
# Collecting ray[default]<3.0.0,>=2.3.0
#   Downloading ray-2.4.0-cp310-cp310-manylinux2014_x86_64.whl (58.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 MB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 55.0 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.2.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 5.6 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (4.3.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (8.1.3)
# Collecting grpcio!=1.52.0,<2.0.0,>=1.48.2
#   Downloading grpcio-1.51.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (1.0.5)
# Collecting virtualenv<20.21.1,>=20.0.24
#   Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 59.1 MB/s eta 0:00:00
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.14-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 57.2 MB/s eta 0:00:00
# Collecting gpustat>=1.0.0
#   Downloading gpustat-1.1.tar.gz (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 8.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: smart-open in /usr/local/lib/python3.10/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (6.3.0)
# Collecting opencensus
#   Downloading opencensus-0.11.2-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 18.0 MB/s eta 0:00:00
# Collecting colorful
#   Downloading colorful-0.5.5-py2.py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (1.10.7)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (0.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Collecting blessed>=1.17.1
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 7.8 MB/s eta 0:00:00
# Collecting nvidia-ml-py>=11.450.129
#   Downloading nvidia_ml_py-11.525.112-py3-none-any.whl (35 kB)
# Requirement already satisfied: psutil>=5.6.0 in /usr/local/lib/python3.10/dist-packages (from gpustat>=1.0.0->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (5.9.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.10/dist-packages (from virtualenv<20.21.1,>=20.0.24->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (3.3.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 47.1 MB/s eta 0:00:00
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (0.19.3)
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opencensus->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (2.11.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (0.2.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (1.59.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (2.17.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<3.0.0,>=2.3.0->flwr[simulation]) (0.5.0)
# Building wheels for collected packages: gpustat
#   Building wheel for gpustat (pyproject.toml) ... done
#   Created wheel for gpustat: filename=gpustat-1.1-py3-none-any.whl size=26298 sha256=cecbbf92c865ce6cdbe4090f08a6589b535bd3b496a032abcde93e33b180d306
#   Stored in directory: /root/.cache/pip/wheels/ee/d0/2c/1e02440645c2318ba03aea99993a44a9108dc8f74de0bd370b
# Successfully built gpustat
# Installing collected packages: tokenizers, py-spy, opencensus-context, nvidia-ml-py, distlib, colorful, xxhash, virtualenv, multidict, iterators, grpcio, frozenlist, dill, blessed, async-timeout, yarl, responses, multiprocess, huggingface-hub, gpustat, flwr, aiosignal, transformers, ray, aiohttp, opencensus, aiohttp-cors, datasets, evaluate
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.54.0
#     Uninstalling grpcio-1.54.0:
#       Successfully uninstalled grpcio-1.54.0
# Successfully installed aiohttp-3.8.4 aiohttp-cors-0.7.0 aiosignal-1.3.1 async-timeout-4.0.2 blessed-1.20.0 colorful-0.5.5 datasets-2.11.0 dill-0.3.6 distlib-0.3.6 evaluate-0.4.0 flwr-1.4.0 frozenlist-1.3.3 gpustat-1.1 grpcio-1.51.3 huggingface-hub-0.14.1 iterators-0.0.2 multidict-6.0.4 multiprocess-0.70.14 nvidia-ml-py-11.525.112 opencensus-0.11.2 opencensus-context-0.1.3 py-spy-0.3.14 ray-2.4.0 responses-0.18.0 tokenizers-0.13.3 transformers-4.28.1 virtualenv-20.21.0 xxhash-3.2.0 yarl-1.9.2

# %% [markdown]
# We can now import the relevant modules.

# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %%
from collections import OrderedDict
import os
import random
import warnings

import flwr as fl
import torch

from torch.utils.data import DataLoader

from datasets import load_dataset
from evaluate import load as load_metric
import evaluate

from transformers import AutoTokenizer, DataCollatorWithPadding
from transformers import AutoModelForSequenceClassification
from transformers import AdamW
from transformers import logging

# %% [markdown]
# Next we will set some global variables and disable some of the logging to clear out our output.

# %%
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
logging.set_verbosity(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
warnings.simplefilter('ignore')

DEVICE = torch.device("cuda")
CHECKPOINT = "albert-base-v2"  # transformer model checkpoint
NUM_CLIENTS = 2
NUM_ROUNDS = 3

# %%
raw_dataset = load_dataset("hate_speech18")['train']
raw_dataset = raw_dataset.filter(lambda x: x['label'] <= 1)

raw_dataset = raw_dataset.sort("label")
raw_dataset = raw_dataset.select(range(9000,10000))
selected_columns = ["label", "text"]
for i, example in enumerate(raw_dataset):
    if i < 1000:
        print({column: example[column] for column in selected_columns})
# Out:
# WARNING:datasets.builder:Found cached dataset hate_speech18 (/root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733)
#   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733/cache-4f52410d5b932a33.arrow
# WARNING:datasets.arrow_dataset:Loading cached sorted indices for dataset at /root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733/cache-da5d517a2cc9429b.arrow
# {'label': 0, 'text': 'Taking money from Oregon taxpayers , while 1500 miles away .'}
# {'label': 0, 'text': 'I wanted to thank you Mjodr for taking the time today to go check out a house there in the area for my family and I to move to .'}
# {'label': 0, 'text': 'We look forward to seeing you all in the PLE very soon .'}
# {'label': 0, 'text': 'That is correct , White men with guns built America , and it will likely take White men with guns to take it back .'}
# {'label': 0, 'text': 'When anyone is ready we are now taking reservations on lots as we speak first come first served contact me for more info .'}
# {'label': 0, 'text': 'http://www.borderwatch.us/ REPORT TO CAMPO , CALIFORNIA FOR DUTY RIGHT AWAY .'}
# {'label': 0, 'text': 'CAMPO SAN DIEGO EAST COUNTY CALIFORNIA On Now thru August 7 , 2005 760 644-0857 Come One Come All !'}
# {'label': 0, 'text': 'www.borderwatch.us/camp.htm http://sandiego.indymedia.org/en/2005/07/109826.shtmlhttp://sandiego.indymedia.org/en/2005/07/109855.shtmlhttp://www.saveourstate.org/forums/i ... topic = 3596 & hl ='}
# {'label': 0, 'text': 'It is a noble idea but I would rather stay here in mostly white Missouri then move to 35 % black South Carolina .'}
# {'label': 0, 'text': 'Gotta have the green grass and trees .'}
# {'label': 0, 'text': 'If you ever hear of something like this in Northern climes , I am very interested .'}
# {'label': 0, 'text': "Thank's, Ill put together a post over on the B & H site in the next couple of days to let people know about the PLE ideas and ask about adding a PLE forum over there ."}
# {'label': 0, 'text': "There are many interesting listings on this web site , including Stormfront 's own Advance Scout forum which teaches the principles of Pioneer Little Europe : http://www.angelfire.com/nv/micronations/usa.html"}
# {'label': 0, 'text': 'The PLE that I join will be centered on MUSIC .'}
# {'label': 0, 'text': 'Live music and dancing .'}
# {'label': 0, 'text': 'Look for my thread ( Oh no !'}
# {'label': 0, 'text': 'Not another promo ) Meet Me at the Footbridge : PLE and the Musicman .'}
# {'label': 0, 'text': 'These are what I am trying to do .'}
# {'label': 0, 'text': 'I think you should try to speak at the EURO Conference this year about the PLE Concept .'}
# {'label': 0, 'text': 'It is a noble idea but I would rather stay here in mostly white Missouri then move to 35 % black South Carolina .'}
# {'label': 0, 'text': 'I would if I liked my neighbors .. There are some people on this board that I would hate to live next to'}
# {'label': 0, 'text': 'Whites shoudl clean their own mess !'}
# {'label': 0, 'text': 'Getting someone else to do our dirty work got us into the mess we are in today .'}
# {'label': 0, 'text': "No, I meant how to get around buying up all the land in a PLE chosen town while refusing nonwhites to buy any property in such an area , it probably would n't matter if a nonwhite bought your house before you joined a PLE ."}
# {'label': 0, 'text': "I've just been reading through quite a few of them and I 'm pleased to say there seems to be quite a degree of support ."}
# {'label': 0, 'text': "As long as they are pro-White and follow board guidelines , I can put up with their `` spin '' ... as long as they 'll put up with mine ."}
# {'label': 0, 'text': "A small trace amounts of non white blood a few generations back can be removed naturally by generational mixing of more white blood into the lifeline of a family who 's great great so on on and so forth engaged in one incident of miscegenation ."}
# {'label': 0, 'text': 'There are entire towns in various parts of Texas I have heard that will kindly show black folks right back the way they came from .'}
# {'label': 0, 'text': 'I think we need to stand our ground and send our enemies away .'}
# {'label': 0, 'text': "We ca n't just keep running to the suburbs ."}
# {'label': 0, 'text': 'this video pretty much proves the local demographics .'}
# {'label': 0, 'text': 'Did you see anything other than white faces in that non racially edited video ?'}
# {'label': 0, 'text': 'The best thing about Thursday fest recently is the home made ice cream they make in front of you with liquid nitrogen !!!'}
# {'label': 0, 'text': "Why did you say you were a member of the `` white knights '' when it appears your a member of the knights party ?"}
# {'label': 0, 'text': "If you are putting bread on a White family 's table , they will follow you ."}
# {'label': 0, 'text': 'Economic empowerment is the way to political success .'}
# {'label': 0, 'text': 'If somebody commits a crime in the name of the klan they are not a real klansman and should be punished by the law as well as anybody that ordered them to commit the criminal acts .'}
# {'label': 0, 'text': 'We are not a criminal organization and there is no place for criminals in the klan .'}
# {'label': 0, 'text': 'Thank you very much for your contribution !'}
# {'label': 0, 'text': 'There are some slight differences between the two - is one of them geared toward whites in general , and the other toward Dutch/Germans ?'}
# {'label': 0, 'text': 'When it happens to your friends they will come to you for advise , and they will see you were right all along .'}
# {'label': 0, 'text': 'Will you all let me know a good couple of months ahead of time so I can sell my house , most of my stuff and go hide in the woods ?'}
# {'label': 0, 'text': 'Thanks !'}
# {'label': 0, 'text': 'I doubt you can actually get close enough to the antis to pass a flower .'}
# {'label': 0, 'text': 'But the camellia idea is great .'}
# {'label': 0, 'text': 'Attention Chicago people Art Jones needs your help in his campaign !'}
# {'label': 0, 'text': 'Go to his web site and check it out and get active .'}
# {'label': 0, 'text': 'Less talk and more activism !'}
# {'label': 0, 'text': 'WWW.ARTJONESINFO.COM'}
# {'label': 0, 'text': 'I have a subway nearby and eat there occasionally .'}
# {'label': 0, 'text': 'The owner is white as are the staff for the most part .'}
# {'label': 0, 'text': 'No problems at all .'}
# {'label': 0, 'text': 'If anyone did or is going too Join a group like the order , In my opinion .... Silence is golden , and keep your mouth shut and your eyes wide open. : hide'}
# {'label': 0, 'text': 'This should be passed to the left too , who have been victims of ADL tactics including theft of police files , smearing , and illegal spying .'}
# {'label': 0, 'text': "Don't know if any of this is obsolete but it 's a start ..."}
# {'label': 0, 'text': 'http://www.spamlaws.com/state/summary.html the site lists all 50 states I believe .'}
# {'label': 0, 'text': "I try to keep up with as many flyers as I can on this site : http://www.whitefreespeech.com/flyers.html And I 'm usually looking for others to add as well ."}
# {'label': 0, 'text': 'Im glad that he quit because he should never have said he was sorry and he is a coward for backing down'}
# {'label': 0, 'text': 'I stop on BET sometimes to reassure my desires to fight their progression and get in the know about their latest crap .'}
# {'label': 0, 'text': 'WhiteUtopian'}
# {'label': 0, 'text': 'It was never yours to begin with .'}
# {'label': 0, 'text': 'South Africa was a country founded by Europeans .'}
# {'label': 0, 'text': 'I do wish you luck in your repatriation to Botswana though .'}
# {'label': 0, 'text': 'OK.'}
# {'label': 0, 'text': "On the basis of this argument , the Haitians had to defend themselves from the French who were `` raping the island of Haiti '' to death ."}
# {'label': 0, 'text': 'Sinners of the past did including your own people who sold you like cattle .'}
# {'label': 0, 'text': 'You should be angry at them not us as they sold you from your own homeland .'}
# {'label': 0, 'text': 'By the way , im against slavery .'}
# {'label': 0, 'text': "I can care less who 's better then who ."}
# {'label': 0, 'text': 'But she went on and on about how great koreans are under the guise of japanese name .'}
# {'label': 0, 'text': 'screw that. it IS about superiority .'}
# {'label': 0, 'text': 'Who said those were Jews from Israel on that chart ?'}
# {'label': 0, 'text': 'How many of these do I have to show you before you catch on ?'}
# {'label': 0, 'text': 'Correct that is the exact goal of the Elite in North America .'}
# {'label': 0, 'text': 'They want to a mixed population since they know that mixed populations have NO center around to rebel .'}
# {'label': 0, 'text': 'Every ethnic Ukrainian I have ever met was White .'}
# {'label': 0, 'text': 'There was no question at any time that they may have some mud in the blood .'}
# {'label': 0, 'text': 'Wonderful people and great food !'}
# {'label': 0, 'text': 'What are you talking about ?'}
# {'label': 0, 'text': 'Those nations are all extremely diverse .'}
# {'label': 0, 'text': 'Thank you for proving our point .'}
# {'label': 0, 'text': "I'm impressesed with the ' if you do n't like it go somewhere else ' and ' herd mentality ' quips . Way to start a civilised debate , non ami ."}
# {'label': 0, 'text': 'Thus Whites have to wait until they become a minority in their own country and then they can have their pride too .'}
# {'label': 0, 'text': 'Huh ?'}
# {'label': 0, 'text': 'Anti-White S.O.B. ` s ?'}
# {'label': 0, 'text': 'What have you got to say for yourselves ?'}
# {'label': 0, 'text': 'Did day kill dem injuns ?'}
# {'label': 0, 'text': 'Dids dey colononialize da new erffs ?'}
# {'label': 0, 'text': 'Did daay getz dat Junglef feeeaaver and rr apes da slabve girls ?'}
# {'label': 0, 'text': 'What the Hell is wrong with you people ?'}
# {'label': 0, 'text': 'What do those pictures have to do with 27 framers of the US Constitution including George Washington , James Madison and Benjamin Franklin being non-Jewish Freemasons ?'}
# {'label': 0, 'text': 'Jesus would be very disappointed in all the so called Christians who are so supportive of Jews .'}
# {'label': 0, 'text': 'They were behind his crucifixion and amongst themselves admit to it .'}
# {'label': 0, 'text': "...You did n't build that ."}
# {'label': 0, 'text': 'Your white skin did .'}
# {'label': 0, 'text': "It 's because white skin allows uv rays to pass through more readily , powering your muscles and brain ."}
# {'label': 0, 'text': 'Stupid theory ?'}
# {'label': 0, 'text': 'Yup and about the same level as white privilege .'}
# {'label': 0, 'text': "Yup, after they get married , some still work and get the idiots to bring over their husbands under the guise of `` family members '' ."}
# {'label': 0, 'text': 'Where it not for the hippies great lie of equality , racial pride of any sort would have never come into being .'}
# {'label': 0, 'text': 'i agree these people are full of themselves . . . and i am white nothing is wrong with a different skin color white people are not better than anyone else'}
# {'label': 0, 'text': "It's much easier to follow the stereotype of White people that their thought controllers fill their minds with ."}
# {'label': 0, 'text': 'This way they can come over here dragging their knuckles to fling their feces at us and call us racists .'}
# {'label': 0, 'text': 'Non Whites hate White people plain and simple.They are taught from birth that White people are the cause of all the problems in the world and every bad thing that happens is because of evil racist White people .'}
# {'label': 0, 'text': 'Prove it wrong .'}
# {'label': 0, 'text': 'Put the crack pipe down moron !'}
# {'label': 0, 'text': "It is nothing short of hysterical that you are such a retard you have to TELL us in your username that you are `` educated . ''"}
# {'label': 0, 'text': 'Did you register an account on this site just to call these people white supremacists/call them stupid ?'}
# {'label': 0, 'text': 'If yes , I think you are doing your people a huge disservice .'}
# {'label': 0, 'text': 'I agree with your post except if its a white they will say so .'}
# {'label': 0, 'text': 'If its a non white they cover it up .'}
# {'label': 0, 'text': 'I repped yez but must spread it around before ...'}
# {'label': 0, 'text': "Wait until the blacks hear about `` Black Douglas '' , or `` The Black Watch '' or `` Black Thursday '' ..."}
# {'label': 0, 'text': 'I tried to sign up there once & they refused to activate my account .'}
# {'label': 0, 'text': "Does n't sound like I 'm missing much anyway ."}
# {'label': 0, 'text': 'i just had my first child , he will be one next week. i will not push my views on him because if you push things on your child they tend to rebel ! my child will learn right from wrong from my positive examples and he will see the truth .'}
# {'label': 0, 'text': "Yep, that 's London for ya ."}
# {'label': 0, 'text': 'Some parts of London are more British than others .'}
# {'label': 0, 'text': 'But a lot of the Whites moved out to Essex and Kent .'}
# {'label': 0, 'text': "Dear genius : Find a statistics text and look up `` normal distribution . ''"}
# {'label': 0, 'text': 'Pay special attention to the concepts of MEAN and VARIANCE .'}
# {'label': 0, 'text': 'These elementary concepts render the rest of your argument entirely invalid .'}
# {'label': 0, 'text': "Don't you know the Jews see a picture like this and laugh their asses off while patting each other on the back ."}
# {'label': 0, 'text': "That's what I 'm saying , even though they had Stone Age tools they were pretty advanced in their knowledge of plants ."}
# {'label': 0, 'text': "By the way , if the person you 're speaking to is claiming that blacks are held back it 's their duty to prove their claim , not your duty to disprove it ."}
# {'label': 0, 'text': "It 's not like cops are running around framing black people for crimes all day ."}
# {'label': 0, 'text': 'I just added up the price of textbooks REQUIRED for an organic chemistry class .'}
# {'label': 0, 'text': 'The total was $ 0.75 shy of $ 400 .'}
# {'label': 0, 'text': "Does anyone else find it does n't difficult to find a white Canadian woman to date who is not Looney lefty ?"}
# {'label': 0, 'text': 'Like they all have gay and lesbian friends for one and if you say you think homosexuality is an abomination then that is your last date .'}
# {'label': 0, 'text': 'Hungary must stick to its guns it is a sad day when sticking to ones guns means simply enforcing the law as proscribed'}
# {'label': 0, 'text': 'Canada is on par or worse than Germany these days for being anti-Nationalist .'}
# {'label': 0, 'text': "I 'd imagine trying to live there as a white nationalist would be extremely hard ."}
# {'label': 0, 'text': "It's wise to think in terms of `` 3 's '' when stocking up ."}
# {'label': 0, 'text': 'Lighting : candles , oil lamps , solar lamps Water : creek , well , spring Potatoes : freshly grown , dehydrated , canned Guns : handgun , rifle , shotgun Transportation : truck , bike , motorcycle The list is almost endless .'}
# {'label': 0, 'text': 'Variety is always better than putting all your eggs in one basket .'}
# {'label': 0, 'text': 'its disgusting how a person color of skin determines whether or not you should give them training to become a doctor to save lives. thats racist .'}
# {'label': 0, 'text': 'My french teacher at school found one way to get us boys to concentrate , put a french woman with big boobs in front of us .'}
# {'label': 0, 'text': 'It worked for the one lesson she was there anyway .'}
# {'label': 0, 'text': "I'm on the south shore ..."}
# {'label': 0, 'text': "If anyone want 's to get together I 'm open to a BBQ with like-minded individuals ."}
# {'label': 0, 'text': 'Let me know !'}
# {'label': 0, 'text': 'We should only support white businesses whose products are made in white countries .'}
# {'label': 0, 'text': 'White money should only be for the benefit of the white race .'}
# {'label': 0, 'text': 'I took a race and ethnicity class at the college I went to .'}
# {'label': 0, 'text': 'I remember the teacher telling everyone that mixed races babies and mixed race peoples are always more healthy that pure bed babies .'}
# {'label': 0, 'text': 'Tiger woods was her example and a few others .'}
# {'label': 0, 'text': 'Hi: I want to share these wonderful videos , very beautiful teachers and great new methods for everybody can easily learn .'}
# {'label': 0, 'text': 'You Tube You Tube You Tube You Tube You Tube Im sorry Im joking this is so funny'}
# {'label': 0, 'text': 'hey remember the Japanese where on the Good side during WW2 on a light note , ya , I can be idolized and all my coworkers , we are all heroes ready to build the next rail gun cannons that will power WW3'}
# {'label': 0, 'text': "She's lucky , I bet she 'll be more careful next time ."}
# {'label': 0, 'text': "There 's nothing else like hot lead to teach you respect for a firearm ."}
# {'label': 0, 'text': 'The Aryan Body , Mind and Soul - Prodigies and Geniuses Dr. William Shockley ( February 13 , 1910 - August 12 , 1989 ) Dr. William Shockley was an American physicist and inventor .'}
# {'label': 0, 'text': 'Along with John Bardeen and Walter Houser Brattain , Shockley co-invented the transistor , for which all three were awarded the 1956 Nobel Prize in Physics .'}
# {'label': 0, 'text': "Shockley 's attempts to commercialize a new transistor design in the 1950s and 1960s led to California 's `` Silicon Valley '' becoming a hotbed of electronics innovation ."}
# {'label': 0, 'text': 'In his later life , Shockley was a professor at Stanford and became a staunch advocate of eugenics .'}
# {'label': 0, 'text': "Dr. David Duke mentions about his friendship with Dr. William Shockley in his latest video ( 6/22/2010 ) titled `` Will the White Race Survive ? '' http://www.youtube.com/watch ? v = RoKl47nK04M"}
# {'label': 0, 'text': 'What he means is to not directly support as far as possible , as opposed to indirectly support the system itself ( via taxes etc ) .'}
# {'label': 0, 'text': 'You need to ask this when the Obama Administration instructed the IRS to target conservatives ?'}
# {'label': 0, 'text': "New Claims That IRS Targeting Of Tea Party Groups Continuing - Trey Gowdy - America 's Newsroom - YouTube"}
# {'label': 0, 'text': 'I went there as a kid and it was great .'}
# {'label': 0, 'text': 'Was .'}
# {'label': 0, 'text': 'Lines ?'}
# {'label': 0, 'text': "I would n't take my kids there without some serious hardcore buddies ."}
# {'label': 0, 'text': 'Neither of the Diaz brothers are very bright but they generally come to fight .'}
# {'label': 0, 'text': "I 'm sure McGregor and Nate will put on a good show but I 'm not forking over $ 50 for one good fight on a ppv"}
# {'label': 0, 'text': 'A punch in the face is a punch in the face regardless of where in the world it happens .'}
# {'label': 0, 'text': 'The effectiveness of any martial are is solely dependent on the person practicing it .'}
# {'label': 0, 'text': 'Ha.'}
# {'label': 0, 'text': 'I was just about to post a similar thread .'}
# {'label': 0, 'text': 'I knew if I waited long enough my university would eventually endorse this crap .'}
# {'label': 0, 'text': "Have you ever seen the `` White Priviledge Checklist '' that these people use ?"}
# {'label': 0, 'text': 'God I hate Canada !'}
# {'label': 0, 'text': 'Ahead of their time , as you said Canada day is not about whites and their progeny who founded this nation anymore .'}
# {'label': 0, 'text': '``Lookhow my family is growing - two new fellas and a baby on the way !'}
# {'label': 0, 'text': 'This is the night he and I got all engaged and stuff .'}
# {'label': 0, 'text': 'X ) `` Stone Family Band : with new in-law at far left and new future in-law at far right .'}
# {'label': 0, 'text': 'While it is hard to compete with the success of the white nationalist front under supreme chairman Goudreau , There are groups and a community here that is working to build up a local movement based on positive activism and friendly gatherings .'}
# {'label': 0, 'text': 'If we got rid of all Asians in the country Canada would be massively white .'}
# {'label': 0, 'text': 'Blacks only account for around 4 percent of the population .'}
# {'label': 0, 'text': 'Animal Grief in the 19th Century Old Shepherd s Chief Mourner by Edwin Henry Landseer , 1827 .'}
# {'label': 0, 'text': 'During the 19th century , attributing human feelings to animals was generally considered to be more sentimentality than science .'}
# {'label': 0, 'text': 'Nevertheless , Regency and Victorian era reports abound of dogs who wasted away at their master s graves , cats who refused to eat or drink upon the death of their mistress , and even a pet monkey who committed suicide .'}
# {'label': 0, 'text': 'Some of these stories were , indeed , mere sentimentalism .'}
# {'label': 0, 'text': 'Others were poignant accounts of the behavior of indisputably grief stricken animals .'}
# {'label': 0, 'text': 'https : //mimimatthews.com/2016/03/03/ ... ampaign = buffer'}
# {'label': 0, 'text': "Every White person on the planet should have easy access to firearms , provided they do n't have a violent criminal past or a history of mental illness ."}
# {'label': 0, 'text': 'Just watched the first few minutes of the video and will finish when I wake up .'}
# {'label': 0, 'text': 'Sounds interesting , thanks for posting it .'}
# {'label': 0, 'text': 'My Father taught me to shoot when I was 12 years old .'}
# {'label': 0, 'text': 'We would go to the range , rifle and pistol , once each week .'}
# {'label': 0, 'text': 'I taught my son when he was 12 .'}
# {'label': 0, 'text': "I think I was my own `` tiger mom '' when in Montessori school ... around age 3 My memories are vague ( cue song ) but Mumsy said they had hoola hoops we sat in and whenever a kid stepped in mine I slapped him/her ."}
# {'label': 0, 'text': 'Yes , I was a Libertarian from birth !'}
# {'label': 0, 'text': 'Cats Musical - Memory - YouTube'}
# {'label': 0, 'text': 'I used to beg my parents to let me wear a boy swimsuit .. trunks and topless when I was 3 or 4 years old .'}
# {'label': 0, 'text': 'Finally , they relented and let me have my first pair of swimming trunks .'}
# {'label': 0, 'text': 'I swam in them once at the beach , and was wearing only swim trunks .. just like the boys .'}
# {'label': 0, 'text': 'It was also the only day I wanted to do that .'}
# {'label': 0, 'text': "Aw c 'mon Hillary is a babe ."}
# {'label': 0, 'text': 'Sharpton just wants to get his hands on da White House fleet of limousines .'}
# {'label': 0, 'text': 'Yup .'}
# {'label': 0, 'text': 'We lose no matter what .'}
# {'label': 0, 'text': "Before I became a Christian when I was a big fan of heavy metal I liked Old lead singer of Gathering Old female singer of Tristania ( my favorite ) 80 's pop was all pretty good too Cyndi Lauper Sanda Kim Wilde"}
# {'label': 0, 'text': 'It is a silly video , but it highlights the nonsensical world in which Jesus lived and the world Jesus was instrumental in changing .'}
# {'label': 0, 'text': "Stoning - Monty Python 's Life of Brian - YouTube"}
# {'label': 0, 'text': "Let's be clear about these Neolithic farmers ."}
# {'label': 0, 'text': 'They were not as dark as , say , a modern Iraqi .'}
# {'label': 0, 'text': 'The Neolithic farmers who migrated into Europe originated in Anatolia .'}
# {'label': 0, 'text': 'According to Mathieson 2015 , they had around a 30 % incidence of blue eyes ( versus around 25 % for the Steppe populations ) and carried the same mutations for light skin that the Steppe people did .'}
# {'label': 0, 'text': 'The native hunter-gatherers , on the other hand , show 100 % incidence of blue eyes but do not have all the same mutations for light skin as the farmer and Steppe populations .'}
# {'label': 0, 'text': 'Lactose tolerance ( again from Mathieson 2015 ) did not exist among either the Steppe pastoralists or the Neolithic farmers , but developed later amongst mixed groups ( their study found the first evidence for lactose tolerance among the Bell Beaker culture ) .'}
# {'label': 0, 'text': 'Show her a William Pierce video on YouTube and then explain it to her .'}
# {'label': 0, 'text': 'She is off this week from school for thanksgiving and my other kids had school still for 2 days so she went with me to school.On way back was explaining to her my side and her mothers side of our heritage and explaining to her where the different countries were and told her we can get a map of Europe and she can color in the countries we are from .'}
# {'label': 0, 'text': 'Well we have lots of shirts that you can order and a different design will be done probably early this next week and we will be putting them up on kijiji as soon as we pick them up .'}
# {'label': 0, 'text': 'Is it where they grade you based on how cultural marxist you are or do they allow people their own views ?'}
# {'label': 0, 'text': "So do you actually meet the people that you let join and start a chapter or are you just trusting that an anti would n't sign up so that you start directing people to them to get jumped or whatever ?"}
# {'label': 0, 'text': 'Do you not realize that goddamn white genicide is upon the white race ?'}
# {'label': 0, 'text': 'Sharpless 249 and the Jellyfish Nebula Image Credit & Copyright : César Blanco González Explanation : Normally faint and elusive , the Jellyfish Nebula is caught in this alluring telescopic mosaic .'}
# {'label': 0, 'text': 'The scene is anchored right and left by two bright stars , Mu and Eta Geminorum , at the foot of the celestial twin while the Jellyfish Nebula is the brighter arcing ridge of emission with dangling tentacles below and right of center .'}
# {'label': 0, 'text': 'In fact , the cosmic jellyfish is part of bubble-shaped supernova remnant IC 443 , the expanding debris cloud from a massive star that exploded .'}
# {'label': 0, 'text': 'Light from the explosion first reached planet Earth over 30,000 years ago .'}
# {'label': 0, 'text': 'Like its cousin in astrophysical waters the Crab Nebula supernova remnant , the Jellyfish Nebula is known to harbor a neutron star , the remnant of the collapsed stellar core .'}
# {'label': 0, 'text': 'An emission nebula cataloged as Sharpless 249 fills the field at the upper left .'}
# {'label': 0, 'text': 'The Jellyfish Nebula is about 5,000 light-years away .'}
# {'label': 0, 'text': 'At that distance , this narrowband composite image would be about 300 light-years across .'}
# {'label': 0, 'text': 'http://apod.nasa.gov/apod/astropix.html'}
# {'label': 0, 'text': 'I became a revisionist after going to Auschwitz 1 and 2 .'}
# {'label': 0, 'text': "I 'm half german , my grandad served in the SS , so I wanted to see what he and his brothers did ."}
# {'label': 0, 'text': 'We were shown the ovens where the bodies were cremated .'}
# {'label': 0, 'text': 'Quoting the guide/historian ( he had a PHD ) here , `` there are 8 beds , each fits one body and it takes roughly 90 mins to completely incinerate a body using the techniques they employed .'}
# {'label': 0, 'text': 'In one year 2.2 million people were incinerated in these very chambers .'}
# {'label': 0, 'text': 'We have a list at the memorial of names `` I was thinking , WTF , grab me a calculator .'}
# {'label': 0, 'text': 'Well , I looked in amazement as everyone bought this rubbish .'}
# {'label': 0, 'text': "I put my hand up and said `` Respectfully , my 9 year old nephew using primary school mathematics and tell you this is totally impossible '' ."}
# {'label': 0, 'text': 'We argued for a bit , then I asked to see the list of names .'}
# {'label': 0, 'text': 'They also threatened to throw me out of the country .'}
# {'label': 0, 'text': 'Obama is by no means a muslim .'}
# {'label': 0, 'text': 'He has the blood of many muslims on his hands .'}
# {'label': 0, 'text': 'He is a jewish puppet .'}
# {'label': 0, 'text': 'And before you ask : Yes I bite my lips .'}
# {'label': 0, 'text': 'Yes I lick my lips and they are in terrible shape .'}
# {'label': 0, 'text': 'I detest chap stick .'}
# {'label': 0, 'text': 'Southern Missouri is very pretty .'}
# {'label': 0, 'text': 'Shannon county is famous for its wild horses and the whole area is timbered and rugged .'}
# {'label': 0, 'text': 'You may want to consider the Harrison Arkansas area as well .'}
# {'label': 0, 'text': 'The town of Houston is the County seat of Texas county I believe .'}
# {'label': 0, 'text': 'Mountain view is a nice little town but remember the area is somewhat impoverished .'}
# {'label': 0, 'text': 'Alley mills spring is an artists dream area .'}
# {'label': 0, 'text': 'http://www.eminencemo.com'}
# {'label': 0, 'text': 'Just buck up and stop being lazy .'}
# {'label': 0, 'text': "Perhaps people will take you more seriously if you do n't make as many grammar errors and using repulsive language ."}
# {'label': 0, 'text': 'I newer mentioned Samis haplogroup types .'}
# {'label': 0, 'text': 'But both Samis and Finns have N1C1 .'}
# {'label': 0, 'text': 'Lager scale .'}
# {'label': 0, 'text': 'Also do some other populations like Estonians , Latvians , Lithuanians , North Russians .'}
# {'label': 0, 'text': 'And in a smaller scales Swedes , Polish , Nowegians etc. in the same area .'}
# {'label': 0, 'text': 'But like I have said many times ... the haplogroup type ALONE will not tell or describe ones whole genetic map or how one looks like .'}
# {'label': 0, 'text': 'Far from that .'}
# {'label': 0, 'text': "And hey , we have not talked about women 's mitochondriat at all ?"}
# {'label': 0, 'text': "Anyway ... they do n't look similar at all between Samis and Finns ."}
# {'label': 0, 'text': 'Mostly gone .'}
# {'label': 0, 'text': 'Everything is machined to well today mlst stuff is plug and play .'}
# {'label': 0, 'text': 'All i see are 1911 smiths , revolver smiths , then machinists who cut crown thread barrels .'}
# {'label': 0, 'text': 'It is a money making scam , that is why it is pushed .'}
# {'label': 0, 'text': "I've had this on my mind most of the day ... it 'll be important to know others in your area who you can network with ."}
# {'label': 0, 'text': 'Find other gardeners , wild plant enthusiasts , and fellow believers in your area who you can band with .'}
# {'label': 0, 'text': "First off I would laugh so hard I 'd turn blue ."}
# {'label': 0, 'text': 'But the truth is he needs a boot party and take our flag back thank you very much .'}
# {'label': 0, 'text': 'Now teachers demand to work just 35 hours a week ... and they even want to be allowed to do five of those at home | Mail Online'}
# {'label': 0, 'text': 'When I was in grammar school I would go to the library every few days and get a new Hardy Boys book .'}
# {'label': 0, 'text': 'They were great mysteries .'}
# {'label': 0, 'text': '...watch this video to the end , lol .'}
# {'label': 0, 'text': "Holocaust Survivor Tells Her Story - YouTube It 's from this channel https : //www.youtube.com/channel/UCML ... wgbpH7gn _ vebtw"}
# {'label': 0, 'text': 'One thing that occurred to me is that the soldiers with those old school battle rifles would have traded them for this Sig in a heartbeat !'}
# {'label': 0, 'text': 'perhaps if you set up the school in a white country then it will catch on and spread to multiracial parts of the world ?'}
# {'label': 0, 'text': "What you say is true but bear in mind that what a person chooses to wear on the outside is a personal statement of what 's on the inside ."}
# {'label': 0, 'text': 'I was just debating with myself whether I should go to bed or have one last beer ...'}
# {'label': 0, 'text': 'Lo and behold , up popped The Beer thread .'}
# {'label': 0, 'text': 'Cheers !'}
# {'label': 0, 'text': "Didn't Sextus solve this problem over a thousand years ago ? `` but amongst the Romans it is forbidden by law to do so ''"}
# {'label': 0, 'text': 'This is my home town .. these people are locals and can help you find what you want ...'}
# {'label': 0, 'text': "I 'll be moving back soon !"}
# {'label': 0, 'text': 'Greeneville TN Homes and Land'}
# {'label': 0, 'text': 'You have to admit that they look like a scrawny desert chicken hence my use of that name over Roadrunner .'}
# {'label': 0, 'text': 'K'}
# {'label': 0, 'text': 'Not so sure this will fit your bill but March of the Titans is a great book on European History .'}
# {'label': 0, 'text': "Here 's a free PDF http://wnlibrary.com/Portabel % 20Docu ... e % 20Titans.pdf"}
# {'label': 0, 'text': 'What is you teaching schedule like ?'}
# {'label': 0, 'text': 'Do you do certain subjects some days or some weeks and others in different days or weeks ?'}
# {'label': 0, 'text': 'How long per day do you go ?'}
# {'label': 0, 'text': 'Do you take weeks off for vacations or trips or just a break ?'}
# {'label': 0, 'text': 'Microsoft , Amazon , Intel , Hewlett Packard all prefer Hindus and Chinese to Americans .'}
# {'label': 0, 'text': 'Have not read the Sagas since I was a kid .'}
# {'label': 0, 'text': 'It always sucks to have your heroes knocked off the pedestal you put them on .'}
# {'label': 0, 'text': 'I have one word for you ....... MOVE . We chose this area because we wanted our children to go to all white schools .'}
# {'label': 0, 'text': "There are quite a few books on Alexander - no need to torture the brain cells trying to decipher someone 's really bad writing ."}
# {'label': 0, 'text': 'The Peter Green book is pretty good .'}
# {'label': 0, 'text': 'It has some interesting appendices as well , as well as maps etc .'}
# {'label': 0, 'text': 'Apparently, many are not yet out of the closet .'}
# {'label': 0, 'text': 'Many of the famous artists , poets , actors , theater/stage actors , home designers , fashion designers , sculptors , ( all of these are artists ) are gay .'}
# {'label': 0, 'text': 'Sorry that you were unaware .'}
# {'label': 0, 'text': 'Have you looked at a fashion magazine lately ??'}
# {'label': 0, 'text': "By the way he did n't film the scene for entertainment but because the negro would have lied and the white would have gotten in trouble so it was to protect himself from any future false accusation ."}
# {'label': 0, 'text': "Don't like the way the cowards kicks Tyrone on the floor then his mate screams like he has won the fight ."}
# {'label': 0, 'text': 'Cowards .'}
# {'label': 0, 'text': 'atrabilious ( ah-truh-BIL-yus ) , adj .'}
# {'label': 0, 'text': '1. morbidly melancholy , 2. irritable ; bad-tempered ; splenetic .'}
# {'label': 0, 'text': 'Also , atrabiliar ( ah-truh-BIL-yar ) [ Origin : 1645 55 ; < L atra bili ( s ) black bile + - ous ] at · ra · bil · ious · ness , n .'}
# {'label': 0, 'text': 'There was a crooked man who walked a crooked mile , he kept a crooked cat in a crooked house for style , he gave a crooked smile in a crooked-minded way , to anyone who suffered on this atrabilious day .'}
# {'label': 0, 'text': "St. John 's College Choir , Cambridge , England : Come , thou long expected Jesus : St John 's College Choir , Cambridge - YouTube St John 's College Choir Cambridge - Wise - Prepare ye the way - YouTube Jesus Christ , the Apple Tree Merry Christmas ( almost ) --last week in Advent !!!!!!"}
# {'label': 0, 'text': 'Erik'}
# {'label': 0, 'text': 'No, I must have two or three kids and teach them to be racially-aware .'}
# {'label': 0, 'text': "Discussing a past historical event does n't `` preserve '' anything ...."}
# {'label': 0, 'text': 'Reproducing does ....'}
# {'label': 0, 'text': 'LA traffic to cause riots during 2 day construction shutdown of 405 fwy .'}
# {'label': 0, 'text': "Los Angeles braces for weekend of `` Carmageddon '' - US news - msnbc.com"}
# {'label': 0, 'text': 'I plan on posting the above quote after every post until this really funny joke thread is done with .'}
# {'label': 0, 'text': 'It should be moved to the really funny joke section .'}
# {'label': 0, 'text': 'If you are talking about Alexander the Great then yes .'}
# {'label': 0, 'text': "It has happened up to the late 90 's with Hong Kong ."}
# {'label': 0, 'text': "``Whiteteacher puts Negro in his place ! ''"}
# {'label': 0, 'text': "No , unfortunately he did n't ."}
# {'label': 0, 'text': 'We Whites are built for grappling .'}
# {'label': 0, 'text': 'Mixed martial arts is generally considered mixing Western and Asian arts together .'}
# {'label': 0, 'text': 'Oh and Pankration was a martial sport not a martial art'}
# {'label': 0, 'text': '1.'}
# {'label': 0, 'text': 'Custom carbine AR ( one of mine will do ) 2 .'}
# {'label': 0, 'text': 'Mossberg 590a1 with bayonet 3 .'}
# {'label': 0, 'text': 'Ak47 with folding stock 4 .'}
# {'label': 0, 'text': 'M & p Vtac 45 5 .'}
# {'label': 0, 'text': 'Remington 700 sps tactical'}
# {'label': 0, 'text': 'yes RoadHog i did check into j and g they sound good , im hoping i will find one on the shelf soon tho , the mosin'}
# {'label': 0, 'text': "I'll update my list a bit ."}
# {'label': 0, 'text': 'CZ-75 Tactical Sports ( 9 mm ) Mossberg shotgun ( 12 gauge ) Finnish RK 95 TP ( 7.62x39 ) M14 with scope ( 7.62x51 ) H & K 416 ( 5.56x45 ) I sort of regret not being able to pick the AKS-74 carbine as my sixth .'}
# {'label': 0, 'text': 'But finding ammunition is important .'}
# {'label': 0, 'text': 'Probably from the two minimum wage part time jobs ........ Oh wait , whites need not apply .'}
# {'label': 0, 'text': 'I forgot .'}
# {'label': 0, 'text': 'Opps .'}
# {'label': 0, 'text': 'Viva la MayheeKo !'}
# {'label': 0, 'text': 'Loopwheels: for a smoother , more comfortable bicycle ride by Sam Pearce & mdash ; Kickstarter https : //s3.amazonaws.com/ksr/assets/ ... jpg ? 1364315377 https : //s3.amazonaws.com/ksr/assets/ ... JPG ? 1366027343 I like the optical illusion of solid mag wheels produced by the spring wheels .'}
# {'label': 0, 'text': 'https : //s3.amazonaws.com/ksr/assets/ ... jpg ? 1365024003'}
# {'label': 0, 'text': 'Yes, precisely !!'}
# {'label': 0, 'text': "If a white person wants to do well at any kind of academic subject , languages , art etc etc. then simply fill your essays with racial integration , feminism and the love of other cultures and the like and you 'll be fine !"}
# {'label': 0, 'text': "It's quite clear you have no argument so you 're now trying to get me to bite with your Jewish nonsense ."}
# {'label': 0, 'text': "I need to dust these off and get them back in my work out routine ... it gives you a feeling of purpose to do these , it helps you connect and relate to the folks they 're named in honor of ."}
# {'label': 0, 'text': 'Every time you see or hear about a British politician fawning over Israel just remember that country was founded by terrorists who killed British soldiers and policemen - www.thetruthseeker.co.uk/ ? p = 119398'}
# {'label': 0, 'text': 'Or the same race that thought the 1st Klan were actual ghosts .'}
# {'label': 0, 'text': 'Now I just need to figure out what you are doing here .'}
# {'label': 0, 'text': "I knew something like this could happen on May 5th American Thinker Blog : Students sent home for wearing American flag on Cinco de Mayo Woooh , the comments section is burnin ' over this Five students sent home for wearing American flag T-shirts on Cinco de Mayo ."}
# {'label': 0, 'text': 'Go to either the school or the board of education and tell them you want to remove your child.Should be some papers you need to sign .'}
# {'label': 0, 'text': 'Really?'}
# {'label': 0, 'text': 'I was always under the impression that the whole sitting down together and being friendly story was a bunch of BS .'}
# {'label': 0, 'text': "Not because the white man was evil , but because the `` natives '' were ."}
# {'label': 0, 'text': 'Interesting .'}
# {'label': 0, 'text': "Two seasons ago this child with her brat-antics and rudeness all but ruined the final weeks of America 's Got Talent , one of the few TV shows I watch and enjoy ."}
# {'label': 0, 'text': 'The LAST thin I want to do is go to her website .'}
# {'label': 0, 'text': 'We attended a large Halloween party at a local church .'}
# {'label': 0, 'text': 'No trick-or-treaters braved our long driveway .'}
# {'label': 0, 'text': 'There are only eight people living within a mile of my house , and none closer than a quarter-mile .'}
# {'label': 0, 'text': "I was dressed as the `` Gorton 's Fisherman ; Trust Me ! '' complete with grey beard , yellow rain-slicker , and ship 's wheel ."}
# {'label': 0, 'text': "My lady was dressed as Scarlett O' Hara ."}
# {'label': 0, 'text': "After the party and kid 's games , there were two dozen little `` houses '' set up in the parking lot for trunk-or-treat candy for the kids ."}
# {'label': 0, 'text': 'Our town has made the heavily-chaperoned Main-Street party the Halloween tradition .'}
# {'label': 0, 'text': 'Very few parents are sending their children out in the dark even in our all-white community .'}
# {'label': 0, 'text': 'The innocence is gone .'}
# {'label': 0, 'text': 'To love ones people in these dark ages is considered a weakness to be exploited .'}
# {'label': 0, 'text': 'We are in the Kali Yuga .'}
# {'label': 0, 'text': 'I saw the movie Valkyrie with Tom Cruise in the lead role .'}
# {'label': 0, 'text': 'It might have been a good film but Cruise really stunk as the German officer .'}
# {'label': 0, 'text': "That's why people have more than one haplogroup again they mark genetic ancestry no one on the planet nowadays only has one ancestor"}
# {'label': 0, 'text': "(Warning: do not watch on a full stomach ) I 'm Jewish And You Know It - Official Parody to Sexy and I know it - YouTube"}
# {'label': 0, 'text': "``Hey,boys, what are ya haulin ' ? '' http://28.media.tumblr.com/tumblr_lb...dmnto1_500.jpg Report : Nuclear weapon drivers sometimes got drunk Buzz up ! 19 votes Share retweet Email Print 2 hrs 20 mins ago WASHINGTON The U.S. Energy Department 's watchdog says [ COLOR = #366388 ! important ] [ COLOR = #366388 ! important ] government [ COLOR = #366388 ! important ] agents [ /COLOR ] [ /COLOR ] [ /COLOR ] hired to drive nuclear weapons and components in trucks sometimes got drunk on the job , including an incident last year when two agents were detained by police at a local bar during a convoy mission ."}
# {'label': 0, 'text': 'Report : Nuclear weapon drivers sometimes got drunk - Yahoo !'}
# {'label': 0, 'text': 'News'}
# {'label': 0, 'text': 'Post the topics discussed in class as they come up on this thread .'}
# {'label': 0, 'text': 'Many of us or our children will be attending school and want to hear what drivel they are dishing out so we will know what to expect .'}
# {'label': 0, 'text': 'I went to trade school when I turned 18 for welding .'}
# {'label': 0, 'text': "In another year I 'll have my B/S in civil engineering ."}
# {'label': 0, 'text': "I've said all there is to be said on your ignorance and with that ; The village idiot , will always be , the village idiot ."}
# {'label': 0, 'text': 'A really good teacher or tutor could have implemented BOTH the interest and the subject into problems .'}
# {'label': 0, 'text': "Instead of just telling the child that 2 + 2 = 4 because the math book said so , they could have put that into a ' problem ' and solution ."}
# {'label': 0, 'text': 'Q : If Timmy can hop a distance of 2 feet and he makes 2 hops , how far did he hop from the starting point to the finishing point ?'}
# {'label': 0, 'text': "A : 4 feet As an exercise , you could get your kids to `` hop '' or step a few times and using a tape measure , figure out their ' average ' stride distance ."}
# {'label': 0, 'text': "If little Timmy has an average ' stride ' of 1 foot , and he walks 6 strides , you would measure ' approximately 6 feet ."}
# {'label': 0, 'text': 'What if Johnny wants to be the quarterback on the football team ?'}
# {'label': 0, 'text': 'Why punish him for not being good at math when you could use the football field as one of the tools to help improve his math skills ?'}
# {'label': 0, 'text': 'Exercise : Get Johnny to pass the football to Jimmy during practice .'}
# {'label': 0, 'text': 'Q : If Johnny was at his own 10 yard line when he threw the ball and Jimmy was at his 30 yard line when he caught the ball , how many yards did Johnny throw the ball ?'}
# {'label': 0, 'text': "A : 20 yards Q : If 3 feet = 1 yard , What distance ( in feet ) was Johnny 's 20 yard football pass ?"}
# {'label': 0, 'text': "A : 60 feet Q : Johnny 's team had the football on the 50 yard line ."}
# {'label': 0, 'text': 'When Jimmy snapped the pass to Johnny he dropped the ball , then recovered it on his own 36 yard line .'}
# {'label': 0, 'text': 'How many yards were lost on that play ?'}
# {'label': 0, 'text': 'How many feet were lost ?'}
# {'label': 0, 'text': "A : 14 yards , or 42 feet Johnny 's ' homeschool math assignment ' could be 10 or 15 problems that he learned on the field that day ."}
# {'label': 0, 'text': 'Maybe it would give him a better appreciation for math if he actually applied it to something while he was having fun .'}
# {'label': 0, 'text': 'Are you a Jew ?'}
# {'label': 0, 'text': '11'}
# {'label': 0, 'text': "Probably be a good idea to call your kid 's teachers and find out what they are learning about so you dont cause your kids to fall behind in their classwork though , and it will send a message to the school that you dont intend to not educate your kids which might get them off your back a bit ."}
# {'label': 0, 'text': 'I sure hope they do that with mine because I have a mental block to all math past adding and subtracting !'}
# {'label': 0, 'text': 'I did ok with my first year of algebra in college ; however , I do know that it is going to get harder !'}
# {'label': 0, 'text': 'Susan'}
# {'label': 0, 'text': 'Who said the Bible was written by the Jews of today ?'}
# {'label': 0, 'text': 'Old Bible scholars beleive the Bible was written by White Germanic people .'}
# {'label': 0, 'text': "The 1st time Jews were even talked about in the Bible was in I Kings and they are at war tring to kill God 's people ( the Hebrews ) ."}
# {'label': 0, 'text': 'The word Jews was not even in old text Bibles .'}
# {'label': 0, 'text': "Most Bibles never used the word Jew untill the late 1700 's ."}
# {'label': 0, 'text': 'The word Jew also had many different meanings in the old days .'}
# {'label': 0, 'text': 'A good book to read on this is a Bible Conderence .'}
# {'label': 0, 'text': 'The word Jew has changed all throughout history .'}
# {'label': 0, 'text': 'The word Jew mean a tribe from Jueda , the word Jew then meant a person living in Jueda , and then it meant a race of people .'}
# {'label': 0, 'text': "The Jews of today have only been a `` race '' since about 1000 AD called Jews ."}
# {'label': 0, 'text': "Kinda proves they are n't the Herbrews of the Bible ."}
# {'label': 0, 'text': "Not once in the Bible are Jesus or God 's people ever called a Jew ."}
# {'label': 0, 'text': 'The only time Jesus is called a Jew , is when the Jews are mocking him on his trail .'}
# {'label': 0, 'text': 'The Jews are called the antichrist , children of Satan , liars , thieves , and murderers throughout the whole Bible .'}
# {'label': 0, 'text': 'I would say more , but I will be bending SF rules .'}
# {'label': 0, 'text': "I'm going to post this one a bit early just in case ."}
# {'label': 0, 'text': 'Not to mention the fact that I had never heard of it anywhere before .'}
# {'label': 0, 'text': 'Nothing special , just a brand spanking new word for me .'}
# {'label': 0, 'text': 'Main Entry : epis · tro · phe Pronunciation : i- \' pis-tr & - ( " ) fE Function : noun Etymology : Greek epistrophE , literally , turning about , from epi - + strophE turning -- more at STROPHE : repetition of a word or expression at the end of successive phrases , clauses , sentences , or verses especially for rhetorical or poetic effect ( as Lincoln \'s `` of the people , by the people , for the people \'\' ) -- compare ANAPHORA'}
# {'label': 0, 'text': 'With that many groups under the same AO , I wonder how much toe stepping is going to occur ... hope none of our own people get hurt .'}
# {'label': 0, 'text': 'This would explain their need to get their people inside every organization including christian churches and force themselves into power positions no matter the cost to anyone else .'}
# ...
# {'label': 1, 'text': "Also some of us on here , like myself , do not believe in the genocide of another race which is what abortion is doing to the Black race as 92 % of abortion clinics are in Black communities , we just do n't believe in race mixing ."}
# {'label': 1, 'text': "It 's just the way they are ."}
# {'label': 1, 'text': '- White GeNOcide Project'}
# {'label': 1, 'text': "You find they are worse since they will able to blend more and fool people into thinking they 're genuine ."}
# {'label': 1, 'text': "And then there 's Asiacourt , the once beautiful , safe , WHITE , area of Scarborough ... ( and the last i checked ) was a garbage infested Chinease outpost ."}
# {'label': 1, 'text': "I considered it being `` ethnically cleansed '' from my childhood home"}
# {'label': 1, 'text': 'When the entire non-White world is breathing down your neck waiting for an opportunity to kill you , anything you do to protect yourself is self-defense .'}
# {'label': 1, 'text': 'I do not blame you , Ottawa like all of our cities is a multicultural hell .'}
# {'label': 1, 'text': 'The race traitors sicken me too .'}
# {'label': 1, 'text': "I suppose they 're trying to be funny , but it 's really just an effort to continue demonizing Germans and propagating the Holocau $ t ."}
# {'label': 1, 'text': "Then again , in this modern age of white youth emulating negroes and white adults groveling at the feet of the juden , perhaps it 's an appropriate word after all ."}
# {'label': 1, 'text': 'I have no doubt Los Angeles is a cess pool .'}
# {'label': 1, 'text': "Don't bother with black culture , it 's not worth the effort ."}
# {'label': 1, 'text': 'All we have is blacks and a few mestizos and all are pretty well behaved , we keep them that way around here'}
# {'label': 1, 'text': 'When I am around young people and rap music or negro culture comes up I make gestures implying the savagery of blacks .'}
# {'label': 1, 'text': 'Gotta represent my coconuts and mangos yo !!'}
# {'label': 1, 'text': 'They mutilate their own , and they do their best to see to it that those whom they see as their goyim slaves are also marked ....'}
# {'label': 1, 'text': 'Their brains have never developed so they think there still in the wild jungles of Africa .'}
# {'label': 1, 'text': 'Having worked around blacks at my previous job every stereotype you hear are all true .'}
# {'label': 1, 'text': 'The only thing that they care about is welfare and mooching of all the rest of us .'}
# {'label': 1, 'text': 'Frederick neichzche embraced the notion that for a race to evolve there had to be a struggle to kill of the weaker elements to keep them from contaminating the gene pool. in the US one could say that there is a breeding program to breed dumb ghetto blacks .'}
# {'label': 1, 'text': 'With the liberal media and police departments under reporting black crime they have been given a pass on their ghetto ways so many times that it as becomes acceptable behavior for them as there is no real consequences for it .'}
# {'label': 1, 'text': "The Negro is generally terrified of Whites , the second you stand up to them they usally back away , thats unless they 're carrying a gun at which point the savages are rarely reluctant to use ."}
# {'label': 1, 'text': "Just because we can `` breed '' does n't mean we should ."}
# {'label': 1, 'text': 'Ya, and they kind of missed the fact that he is going to inner city schools teaching the monkeys how to better kick your white butt !'}
# {'label': 1, 'text': "Back when I was a kid , even the black folks called them that .... `` Ooohhh I' z cai n't wait until Crimusz , I' z gonna get me sum of dem niggah-toes and oranguz fo ' Crimusz , an ' sum peppahmintz ; dey shoa iz gud ! ''"}
# {'label': 1, 'text': "If you want to see what having a black , kenyan White-hating muslime in the Whitehouse has created , go look at Tarantino 's latest flick Django Unchained ."}
# {'label': 1, 'text': 'yeah it just jews stealing stuff from other martial arts. dont worry about it unless they try to recruit you for the mossad'}
# {'label': 1, 'text': 'Instead it is the athletic negro Holyfield 11 kids , Mike Tyson 7 kids , Riddick Bowe 5 kids , George Foreman 10 kids who procreate like apes and spread these athlete genes along .'}
# {'label': 1, 'text': "Remind them that they 're just another Jew tool and that they are basically spitting on the graves of millions of people that were murdered by real Communists ."}
# {'label': 1, 'text': 'Deanna Spingola and Dr. Lorraine Day - Zionism , the Holocaust , Aids and Vaccines YouTube - Deanna Spingola and Dr. Lorraine Day - Zionism , the Holocaust , Aids and Vaccines Listen/watch the full interview @ Deanna Spingola and Dr. Lorraine Day - Zionism , the Holocaust , Aids and Vaccines : Free Download & Streaming : Internet Archive www.DrDay.com www.GoodNewsAboutGod.com'}
# {'label': 1, 'text': "It's weird most Indians dot and to an extent feather that I deal with hate blacks more than they do whites and find blacks to be lazy and worthless ."}
# {'label': 1, 'text': 'There are lots of brown and black kids in the system gays could adopt .'}
# {'label': 1, 'text': 'I do think abusive parents are worse than gays one .'}
# {'label': 1, 'text': "That 's to assume the gay ones are n't abusive ."}
# {'label': 1, 'text': "Many Asians will see something once and memorize it the rest of their lives , but when asked ' how ' it works or use it creatively , they draw a blank ."}
# {'label': 1, 'text': 'Intellectual morons , or educated idiots , are good phrases to describe them .'}
# {'label': 1, 'text': 'why did god give negroes good rhythm ?? because he messed up their lips , hair , nose and skin so yes they are ugly !!!!!!!!!!!!!!'}
# {'label': 1, 'text': 'I bet you can see the Mexic-ants from space with the Google Earth. photo ants on picnic table CYF salt of the earth'}
# {'label': 1, 'text': 'Jews are the most demanding and worst patients of all .'}
# {'label': 1, 'text': 'Pornography and prostitution should be outlawed as the jewish filth that it is . _ _ _ _ _ _ _ _ _ nazi.org.uk'}
# {'label': 1, 'text': 'God forbid anyone should promote straight racially loyal hetrosexuality Diablo'}
# {'label': 1, 'text': 'things u put on yer teeth just kidding ... seen guys with those things that suppose to hold up pants ? theyre red or white ? and theyre not belts. welcome to skinhead charades .'}
# {'label': 1, 'text': "Maybe blacks are n't better , but their body is more shaped to hunt animals ."}
# {'label': 1, 'text': 'The whites and the asians evoluated , and the blacks are still behind .'}
# {'label': 1, 'text': 'I know how you feel BreakTheSilence luckily this is your last year in school and it is almost over otherwise I would say you should look into independent study where you do not have to put up with all the filth that is in the public education system .'}
# {'label': 1, 'text': 'i live up the block from a muslim mask. every friday they rule the streets. they think that they can walk anywhere they want and if your are white they give you a look just klike when you pass through a black neighborhood. they are the same as them nigs'}
# {'label': 1, 'text': 'So please Zuma be a good little kaffir and take their land'}
# {'label': 1, 'text': 'My wife had to spend time at the UP Hospital in Philadelphia - thank God I was licensed to carry in Pa. Downtown Philadelphia is becoming a cesspool .'}
# {'label': 1, 'text': 'They are culturally raping european countries in every way .'}
# {'label': 1, 'text': 'Liberal is just the PC word for Rapist .'}
# {'label': 1, 'text': 'Do non Whites really think they measure up to Whites ?'}
# {'label': 1, 'text': 'Every white person from Michigan knows that our Detroit negros are the worst in America .'}
# {'label': 1, 'text': 'General1812 I think maybe they now starting to have cold feet ; as the race who have feed them will die out .'}
# {'label': 1, 'text': 'Yep the bottom line is without a strong family behind her a young girl is very vulnerable .. The Jew knows this and Glamorises the Negro using its media power , here we see the results .'}
# {'label': 1, 'text': '`` Those evil Whites .'}
# {'label': 1, 'text': 'We have to kill off all of the Whites so we can go back to eating cow dung ! "'}
# {'label': 1, 'text': 'They are too dung stupid to be able to tap into the market .'}
# {'label': 1, 'text': 'They would be better off just sitting out in the sun eating a dirt sundae .'}
# {'label': 1, 'text': "I always thought it would be cool if somebody covertly set off a nuke in Kashmir , and then we all could sit back and watch as the Paki 's and Indians nuke the scheiss out of each other ."}
# {'label': 1, 'text': 'May they just need to turn these savages loose , justice will take care of itself .'}
# {'label': 1, 'text': 'Just let Shaniqua leave her kids home to burn the house down while she goes to da club .'}
# {'label': 1, 'text': 'These groids went haywire when they got in there and found themselves a white girl .'}
# {'label': 1, 'text': "That 's every groid 's wish anyways ."}
# {'label': 1, 'text': "String ' em up !"}
# {'label': 1, 'text': "They do what they always do take something of someone else 's and make it their own ."}
# {'label': 1, 'text': 'We can work together and look after each other which blacks cant. We can think as individuals and do things because they are right and not because we are told to , which asians cant.'}
# {'label': 1, 'text': 'Sadly that is what happens when you dumb down a society and make everything sexual.Not even innocent animals are out of the question for these sickos .'}
# {'label': 1, 'text': 'Crippin nigga .'}
# {'label': 1, 'text': 'WE CRIPPIN NIGGA .'}
# {'label': 1, 'text': 'WE GOT MONEY AROUND HERE TOO Compton Crips Pt.1 - YouTube These negroes are in the middle of the street , seems like something of a zoo , playing with their cheap lowriders .'}
# {'label': 1, 'text': 'Humans and negroes use restaurants in entirely different ways .'}
# {'label': 1, 'text': 'Most of these videos belong on the Animal Planet tv channel .'}
# {'label': 1, 'text': 'Blacks seem to be hell bent on embarrassing themselves and acting like animals everywhere they go .. this is pretty typical behaviour ..'}
# {'label': 1, 'text': "Me thinks Genesis is a negro who thinks he 's from the line of Adam.A troll , confused , black and prowling Stormfront.So make the Revelation Genesis - what are you really up to ?"}
# {'label': 1, 'text': 'Hispanics , Blacks and Asians are all doing it .'}
# {'label': 1, 'text': "of course they wo n't. they just want to steal our land. they would n't stop until we are all dead. and neither would we ."}
# {'label': 1, 'text': 'The only thing more disgusting than a White woman with a groid is a White woman who drags her White child into the filth with her .'}
# {'label': 1, 'text': "zpridez NO big deal , I got your drift.IMO If these bellyaching Black peoples et al continue to negate/or ignore the present ' Products of Progress ' within society we 're all doomed ."}
# {'label': 1, 'text': 'i love it when jews get a taste of thier own vile medicene I hope each and every one of them young to old starve in the cold'}
# {'label': 1, 'text': "Don't eat a Snickers candy bar ... it will turn you into a negro ! ( Also has the obligatory White doofus guy at the end. )"}
# {'label': 1, 'text': "Since they are just little kids i do n't want to be rude , but how ugly is the black kid compared to the others ? it 's not even adorable , it 's kinda scary lol"}
# {'label': 1, 'text': 'The only way to deal with these animals is to give them a one way ticket to their filthy pig god .'}
# {'label': 1, 'text': "Every f * cking school child knows that the Globe is round , only total PIZDAS do n't ."}
# {'label': 1, 'text': "Any purported `` holy book '' which says such vile & despicable things as the talmud says about Mary & Jesus cannot come from a place of goodness.Jews are so convinced of their superiority that they think they can trick God of their love & fidelity by pretending to honor him ."}
# {'label': 1, 'text': 'Situation in Switzerland is terrible , blacks and muslims are everywhere ! We were a great Country with a great People but all these monkeys are transforming Switzerland in a zoo where law is not respected .'}
# {'label': 1, 'text': 'Prostitution and drug is getting everywhere , dealers are from Senegal , Guinea , Nigeria , dirty prostitutes are fom Cameroun .'}
# {'label': 1, 'text': 'Charming is knowing that all these unuseful beings lives in Switzerland as refugees !!!!'}
# {'label': 1, 'text': "I had the luck ( ... ) to meet some africans in the past and I promise you that black are the worse cancer of the world , they 're ready to sell their own sister so you can imagine what will they do with our Countries .."}
# {'label': 1, 'text': 'Keep Russia free from dark skinned beings !!!! thank you and please forgive me for mistakes .'}
# {'label': 1, 'text': 'The point is not the throne itself but the reason for it and what it represents to the apes fighting and tramping for it .'}
# {'label': 1, 'text': 'The natural royality of the planet was not the posing apes , but the Overman .'}
# {'label': 1, 'text': "If you search around you can probably find `` hoax of the 20th century '' for free on the net ."}
# {'label': 1, 'text': 'How on earth can they be Swedes when they are the result of race treason ?'}
# {'label': 1, 'text': 'They are anything but Swedes and to be honest it is good to get rid of them .'}
# {'label': 1, 'text': "We've had a couple of similar cases in Finland , when a nig purposefully tried to give dozens of Finnish women hiv/aids ."}
# {'label': 1, 'text': "If you think that 's funny , you should have seen the black guy that used to run around my home town wearing a kkk emblem.But people like that are usualy not that bright ."}
# {'label': 1, 'text': 'Beautiful Sweden poisoned by Arab/Muslim trash .'}
# {'label': 1, 'text': 'So that excludes uneducated third worlders .'}
# {'label': 1, 'text': "Put the mudraces in their own countries , build a fence around them and wait a decade or two , and soon they 'll be back to the state we found them in , with their numbers decimated by their diseases and wars ."}
# {'label': 1, 'text': "It's people like this that are the face that represents the filth of Islam ."}
# {'label': 1, 'text': 'To be honest .. i dont think this Muslim killed him because he thought the swedish boy looked like a racist ... it was probably just an excuse .'}
# {'label': 1, 'text': 'Islam is not compatible with our way of life in this green and pleasant isle.Irish people are white and Christian FFS !'}
# {'label': 1, 'text': 'They have been taking advantage of our over-welcoming nature for far to long .'}
# {'label': 1, 'text': "If we do n't act soon they will bread us out ."}
# {'label': 1, 'text': 'I heard from friends in Boston this is true.Blacks will attack an Irish America with a shamrock tattoo.How long before this happens in Ireland ?'}
# {'label': 1, 'text': 'Hopefully they will get deportation orders and be on the next flight back to Cairo .'}
# {'label': 1, 'text': "Ireland does n't need arab scum like these ."}
# {'label': 1, 'text': 'Do they expect us to go out and welcome these leeches on our society with open arms. they should give them zyklon b for lunch , thad would help the suitation !!!'}
# {'label': 1, 'text': "Beware of the falling house prices that Negroes bring with them ( another reason why you 'll never find them living near politicans ) ."}
# {'label': 1, 'text': "When I look at the Zimbawee 's Mugabe , I think `` Ape '' or `` Gorilla '' ."}
# {'label': 1, 'text': "Mass white immigration is Ireland 's current scourge and should be slashed by 95-97 % .."}
# {'label': 1, 'text': 'the white race will soon be on the brink of being a minority in a few years if nothing is done to stop these vile hordes invading our lands , I for one do not want to live in a city like Bradford or Birmingham where we are outnumbered 2 to 1 or worse'}
# {'label': 1, 'text': 'yeah but you live in a big country , N. Ireland is quite small yet large numbers of the scum are invading these shores every day'}

# %%
def load_data(cid, num_clients=NUM_CLIENTS):
    """Load HATE data (training and eval)"""

    tokenizer = AutoTokenizer.from_pretrained(CHECKPOINT)
    def tokenize_function(examples):
        return tokenizer(examples["text"], truncation=True)

    if NOISY_DATA:
      #use dataset we made noisy

      #load the train split
      raw_dataset = load_dataset('csv', data_files='train.csv')
      #load the test split and place into noisy_hate_ds as test split
      test = load_dataset('csv', data_files='test.csv')
      raw_dataset['test'] = test['train']
    else:
      #use dataset from huggingface

      #the dataset came with just the train split
      raw_dataset = load_dataset("hate_speech18")['train']

      #remove rows that are not hate/nohate labels
      raw_dataset = raw_dataset.filter(lambda x: x['label'] <= 1)

      #make the dataset smaller
      #raw_dataset = raw_dataset.select(range(1024))

      #balance the dataset
      raw_dataset = raw_dataset.sort("label")
      raw_dataset = raw_dataset.select(range(9000,10000))

      #shuffle
      raw_dataset = raw_dataset.shuffle(seed=42)

      #remove unused columns
      raw_dataset = raw_dataset.remove_columns(["user_id", 'subforum_id', 'num_contexts'])

    #tokenize
    tokenized_datasets = raw_dataset.map(tokenize_function, batched=True)

    #clean up cols
    tokenized_datasets = tokenized_datasets.remove_columns("text")
    tokenized_datasets = tokenized_datasets.rename_column("label", "labels")

    #take the data data out of the old split and split it again
    split_token_dataset = tokenized_datasets.train_test_split(test_size=0.2)


    if POISON_TRAIN:
      #get the training labels
      train_labels = split_token_dataset['train']['labels']

      #flip some of the train labels to poison
      zero_flips = 0
      one_flips = 0
      for i in range(1000):
        if zero_flips < 15 and train_labels[i] == 0:
          train_labels[i] = 1
          zero_flips += 1
        elif one_flips < 15 and train_labels[i] == 1:
          train_labels[i] = 0
          one_flips += 1
        elif zero_flips >= 15 and one_flips >= 15:
          break
        else:
          continue

      #replace the old labels with the poisoned labels
      poisoned_train = split_token_dataset['train'].map(lambda row, idx: {"labels": train_labels[idx]}, with_indices=True, remove_columns=["labels"])

      split_token_dataset['train'] = poisoned_train



    #create loaders
    data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
    trainloader = DataLoader(
        split_token_dataset["train"],
        shuffle=True,
        batch_size=32,
        collate_fn=data_collator,
    )

    testloader = DataLoader(
        split_token_dataset["test"], batch_size=32, collate_fn=data_collator
    )

    return trainloader, testloader
# Out:
# WARNING:datasets.builder:Found cached dataset hate_speech18 (/root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733)
#   0%|          | 0/1 [00:00<?, ?it/s]
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733/cache-d4086989e910d451.arrow
# WARNING:datasets.arrow_dataset:Loading cached sorted indices for dataset at /root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733/cache-ecfa72b3c613b13f.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733/cache-ead923a268c4ff5d.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733/cache-b90fee587593b8ba.arrow
# WARNING:datasets.arrow_dataset:Loading cached split indices for dataset at /root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733/cache-10b3c520f856f9bf.arrow and /root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733/cache-437387c9ebd7a9f1.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/hate_speech18/default/0.0.0/775598e7a56b8706cb7cc3781ce7abd83f8a6d0831d6363f1c93b5f963d7c733/cache-2c7b8e89a6c56944.arrow
# Dataset({
#     features: ['text', 'user_id', 'subforum_id', 'num_contexts', 'label'],
#     num_rows: 10944
# })
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 800
#     })
#     test: Dataset({
#         features: ['labels', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 200
#     })
# })

# %% [markdown]
# ## Standard Hugging Face workflow
#
# ### Handling the data
#
# To fetch the IMDB dataset, we will use Hugging Face's `datasets` library. We then need to tokenize the data and create `PyTorch` dataloaders, this is all done in the `load_data` function:

# %%
def load_data(cid, num_clients=NUM_CLIENTS):
    """Load HATE data (training and eval)"""

    tokenizer = AutoTokenizer.from_pretrained(CHECKPOINT)
    def tokenize_function(examples):
        return tokenizer(examples["text"], truncation=True)

    #the dataset came with just the train split
    raw_dataset = load_dataset("hate_speech18")['train']

    #remove rows that are not hate/nohate labels
    raw_dataset = raw_dataset.filter(lambda x: x['label'] <= 1)

    #make the dataset smaller
    #raw_dataset = raw_dataset.select(range(1024))

    #balance the dataset
    raw_dataset = raw_dataset.sort("label")
    raw_dataset = raw_dataset.select(range(9000,10000))

    #shuffle
    raw_dataset = raw_dataset.shuffle(seed=42)

    #remove unused columns
    raw_dataset = raw_dataset.remove_columns(["user_id", 'subforum_id', 'num_contexts'])

    #tokenize
    tokenized_datasets = raw_dataset.map(tokenize_function, batched=True)

    #clean up cols
    tokenized_datasets = tokenized_datasets.remove_columns("text")
    tokenized_datasets = tokenized_datasets.rename_column("label", "labels")

    #take the data data out of the old split and split it again
    split_token_dataset = tokenized_datasets.train_test_split(test_size=0.1)

    #create loaders
    data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
    trainloader = DataLoader(
        split_token_dataset["train"],
        shuffle=True,
        batch_size=32,
        collate_fn=data_collator,
    )

    testloader = DataLoader(
        split_token_dataset["test"], batch_size=32, collate_fn=data_collator
    )

    return trainloader, testloader

# %% [markdown]
# ### Training and testing the model
#
# Once we have a way of creating our trainloader and testloader, we can take care of the training and testing. This is very similar to any `PyTorch` training or testing loop:

# %%
def train(net, trainloader, epochs):
    optimizer = AdamW(net.parameters(), lr=5e-5)
    net.train()
    for _ in range(epochs):
        for batch in trainloader:
            batch = {k: v.to(DEVICE) for k, v in batch.items()}
            outputs = net(**batch)
            loss = outputs.loss
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()


def test(net, testloader):
    #metric = load_metric("accuracy")
    metric = evaluate.combine(["accuracy", "f1", "precision", "recall"])

    loss = 0
    net.eval()
    for batch in testloader:
        batch = {k: v.to(DEVICE) for k, v in batch.items()}
        with torch.no_grad():
            outputs = net(**batch)
        logits = outputs.logits
        loss += outputs.loss.item()
        predictions = torch.argmax(logits, dim=-1)
        metric.add_batch(predictions=predictions, references=batch["labels"])
    loss /= len(testloader.dataset)
    finalMetrics = metric.compute()

    return loss, finalMetrics

# %% [markdown]
# ### Creating the model itself
#
# To create the model itself, we will just load the pre-trained alBERT model using Hugging Face’s `AutoModelForSequenceClassification` :

# %%
net = AutoModelForSequenceClassification.from_pretrained(
    CHECKPOINT, num_labels=2
).to(DEVICE)

# %% [markdown]
# ## Federating the example
#
# The idea behind Federated Learning is to train a model between multiple clients and a server without having to share any data. This is done by letting each client train the model locally on its data and send its parameters back to the server, which then aggregates all the clients’ parameters together using a predefined strategy. This process is made very simple by using the [Flower](https://github.com/adap/flower) framework. If you want a more complete overview, be sure to check out this guide: [What is Federated Learning?](https://flower.dev/docs/tutorial/Flower-0-What-is-FL.html)
#
# ### Creating the IMDBClient
#
# To federate our example to multiple clients, we first need to write our Flower client class (inheriting from `flwr.client.NumPyClient`). This is very easy, as our model is a standard `PyTorch` model:

# %%
class HATEClient(fl.client.NumPyClient):
    def __init__(self, net, trainloader, testloader):
        self.net = net
        self.trainloader = trainloader
        self.testloader = testloader

    def get_parameters(self, config):
        return [val.cpu().numpy() for _, val in self.net.state_dict().items()]

    def set_parameters(self, parameters):
        params_dict = zip(self.net.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
        self.net.load_state_dict(state_dict, strict=True)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        print("Training Started...")
        train(self.net, self.trainloader, epochs=1)
        print("Training Finished.")
        return self.get_parameters(config={}), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        loss, accuracy, finalMetrics = test(self.net, self.testloader)
        finalMetrics["loss"] = loss
        #return float(loss), len(self.testloader), {"accuracy": float(accuracy), "loss": float(loss)}
        return float(loss), len(self.testloader), finalMetrics

# %% [markdown]
# The `get_parameters` function lets the server get the client's parameters. Inversely, the `set_parameters` function allows the server to send its parameters to the client. Finally, the `fit` function trains the model locally for the client, and the `evaluate` function tests the model locally and returns the relevant metrics.

# %% [markdown]
# ### Generating the clients
#
# In order to simulate the federated setting we need to provide a way to instantiate clients for our simulation. Here, it is very simple as every client will hold the same piece of data (this is not realistic, it is just used here for simplicity sakes).

# %%
def client_fn(cid):
  trainloader, testloader = load_data(cid)
  return HATEClient(net, trainloader, testloader)

# %% [markdown]
# ## Starting the simulation
#
# We now have all the elements to start our simulation. The `weighted_average` function is there to provide a way to aggregate the metrics distributed amongst the clients (basically to display a nice average accuracy at the end of the training). We then define our strategy (here `FedAvg`, which will aggregate the clients weights by doing an average).
#
# Finally, `start_simulation` is used to start the training.

# %%
def weighted_average(metrics):
  f1s = [num_examples * m["f1"] for num_examples, m in metrics]
  precisions = [num_examples * m["precision"] for num_examples, m in metrics]
  recalls = [num_examples * m["recall"] for num_examples, m in metrics]

  accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
  losses = [num_examples * m["loss"] for num_examples, m in metrics]
  examples = [num_examples for num_examples, _ in metrics]
  return {"accuracy": sum(accuracies) / sum(examples),
          "loss": sum(losses) / sum(examples),
          "f1": sum(f1s) / sum(examples),
          "precision": sum(precisions) / sum(examples),
          "recall": sum(recalls) / sum(examples)}

strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,
    fraction_evaluate=1.0,
    evaluate_metrics_aggregation_fn=weighted_average,
)

fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
    strategy=strategy,
    client_resources={"num_cpus": 1, "num_gpus": 1},
    ray_init_args={"log_to_driver": False, "num_cpus": 1, "num_gpus": 1}
)
# Out:
# INFO flwr 2023-04-10 22:01:50,023 | app.py:145 | Starting Flower simulation, config: ServerConfig(num_rounds=3, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=3, round_timeout=None)
# 2023-04-10 22:01:53,827	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# INFO flwr 2023-04-10 22:01:54,378 | app.py:179 | Flower VCE: Ray initialized with resources: {'accelerator_type:A100': 1.0, 'CPU': 1.0, 'GPU': 1.0, 'node:172.28.0.12': 1.0, 'memory': 53327727822.0, 'object_store_memory': 26663863910.0}
# INFO:flwr:Flower VCE: Ray initialized with resources: {'accelerator_type:A100': 1.0, 'CPU': 1.0, 'GPU': 1.0, 'node:172.28.0.12': 1.0, 'memory': 53327727822.0, 'object_store_memory': 26663863910.0}
# INFO flwr 2023-04-10 22:01:54,380 | server.py:86 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2023-04-10 22:01:54,384 | server.py:270 | Requesting initial parameters from one random client
# INFO:flwr:Requesting initial parameters from one random client
# INFO flwr 2023-04-10 22:02:01,583 | server.py:274 | Received initial parameters from one random client
# INFO:flwr:Received initial parameters from one random client
# INFO flwr 2023-04-10 22:02:01,585 | server.py:88 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# INFO flwr 2023-04-10 22:02:01,589 | server.py:101 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2023-04-10 22:02:01,592 | server.py:215 | fit_round 1: strategy sampled 2 clients (out of 2)
# DEBUG:flwr:fit_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-04-10 22:02:23,122 | server.py:229 | fit_round 1 received 2 results and 0 failures
# DEBUG:flwr:fit_round 1 received 2 results and 0 failures
# WARNING flwr 2023-04-10 22:02:23,224 | fedavg.py:242 | No fit_metrics_aggregation_fn provided
# WARNING:flwr:No fit_metrics_aggregation_fn provided
# DEBUG flwr 2023-04-10 22:02:23,226 | server.py:165 | evaluate_round 1: strategy sampled 2 clients (out of 2)
# DEBUG:flwr:evaluate_round 1: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-04-10 22:02:40,326 | server.py:179 | evaluate_round 1 received 2 results and 0 failures
# DEBUG:flwr:evaluate_round 1 received 2 results and 0 failures
# DEBUG flwr 2023-04-10 22:02:40,328 | server.py:215 | fit_round 2: strategy sampled 2 clients (out of 2)
# DEBUG:flwr:fit_round 2: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-04-10 22:03:01,993 | server.py:229 | fit_round 2 received 2 results and 0 failures
# DEBUG:flwr:fit_round 2 received 2 results and 0 failures
# DEBUG flwr 2023-04-10 22:03:02,105 | server.py:165 | evaluate_round 2: strategy sampled 2 clients (out of 2)
# DEBUG:flwr:evaluate_round 2: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-04-10 22:03:19,161 | server.py:179 | evaluate_round 2 received 2 results and 0 failures
# DEBUG:flwr:evaluate_round 2 received 2 results and 0 failures
# DEBUG flwr 2023-04-10 22:03:19,164 | server.py:215 | fit_round 3: strategy sampled 2 clients (out of 2)
# DEBUG:flwr:fit_round 3: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-04-10 22:03:40,790 | server.py:229 | fit_round 3 received 2 results and 0 failures
# DEBUG:flwr:fit_round 3 received 2 results and 0 failures
# DEBUG flwr 2023-04-10 22:03:40,902 | server.py:165 | evaluate_round 3: strategy sampled 2 clients (out of 2)
# DEBUG:flwr:evaluate_round 3: strategy sampled 2 clients (out of 2)
# DEBUG flwr 2023-04-10 22:03:57,544 | server.py:179 | evaluate_round 3 received 2 results and 0 failures
# DEBUG:flwr:evaluate_round 3 received 2 results and 0 failures
# INFO flwr 2023-04-10 22:03:57,547 | server.py:144 | FL finished in 115.95464312000001
# INFO:flwr:FL finished in 115.95464312000001
# INFO flwr 2023-04-10 22:03:57,552 | app.py:202 | app_fit: losses_distributed [(1, 0.021836645305156707), (2, 0.012557988017797471), (3, 0.00966618899255991)]
# INFO:flwr:app_fit: losses_distributed [(1, 0.021836645305156707), (2, 0.012557988017797471), (3, 0.00966618899255991)]
# INFO flwr 2023-04-10 22:03:57,554 | app.py:203 | app_fit: metrics_distributed {'accuracy': [(1, 0.785), (2, 0.86), (3, 0.95)], 'loss': [(1, 0.021836645305156707), (2, 0.012557988017797471), (3, 0.00966618899255991)], 'f1': [(1, 0.7581254724111868), (2, 0.857201309328969), (3, 0.9556194125159642)], 'precision': [(1, 0.7747368421052632), (2, 0.8244318181818182), (3, 0.938828967642527)], 'recall': [(1, 0.7446705426356589), (2, 0.8933007985803016), (3, 0.9730221780867263)]}
# INFO:flwr:app_fit: metrics_distributed {'accuracy': [(1, 0.785), (2, 0.86), (3, 0.95)], 'loss': [(1, 0.021836645305156707), (2, 0.012557988017797471), (3, 0.00966618899255991)], 'f1': [(1, 0.7581254724111868), (2, 0.857201309328969), (3, 0.9556194125159642)], 'precision': [(1, 0.7747368421052632), (2, 0.8244318181818182), (3, 0.938828967642527)], 'recall': [(1, 0.7446705426356589), (2, 0.8933007985803016), (3, 0.9730221780867263)]}
# INFO flwr 2023-04-10 22:03:57,556 | app.py:204 | app_fit: losses_centralized []
# INFO:flwr:app_fit: losses_centralized []
# INFO flwr 2023-04-10 22:03:57,559 | app.py:205 | app_fit: metrics_centralized {}
# INFO:flwr:app_fit: metrics_centralized {}
# History (loss, distributed):
# 	round 1: 0.021836645305156707
# 	round 2: 0.012557988017797471
# 	round 3: 0.00966618899255991
# History (metrics, distributed):
# {'accuracy': [(1, 0.785), (2, 0.86), (3, 0.95)], 'loss': [(1, 0.021836645305156707), (2, 0.012557988017797471), (3, 0.00966618899255991)], 'f1': [(1, 0.7581254724111868), (2, 0.857201309328969), (3, 0.9556194125159642)], 'precision': [(1, 0.7747368421052632), (2, 0.8244318181818182), (3, 0.938828967642527)], 'recall': [(1, 0.7446705426356589), (2, 0.8933007985803016), (3, 0.9730221780867263)]}

# %% [markdown]
# Note that this is a very basic example, and a lot can be added or modified, it was just to showcase how simply we could federate a Hugging Face workflow using Flower. The number of clients and the data samples are intentionally very small in order to quickly run inside Colab, but keep in mind that everything can be tweaked and extended.
